# %% [markdown]
# # Atypical Quantum Maps, Analysis

# %%
import sys
sys.path.insert(0, '../../src_tf/')

import numpy as np
import matplotlib.pyplot as plt

from quantum_channel import channel_spectrum
from utils import loader

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
plt.rcParams["figure.autolayout"] = True

# %% [markdown]
# ## Four Qubits

# %%
[[channel_target1, channel_target2, channel_target3, channel_target4],
 [model1, model2, model3, model4]]= loader("data/"+"atypical_maps_benchmark.model")

spectrum_target1 = channel_spectrum(channel_target1, keep_unity=False)
spectrum_target2 = channel_spectrum(channel_target2, keep_unity=False)
spectrum_target3 = channel_spectrum(channel_target3, keep_unity=False)
spectrum_target4 = channel_spectrum(channel_target4, keep_unity=False)

spectrum_model1 = channel_spectrum(model1.channel, keep_unity=False)
spectrum_model2 = channel_spectrum(model2.channel, keep_unity=False)
spectrum_model3 = channel_spectrum(model3.channel, keep_unity=False)
spectrum_model4 = channel_spectrum(model4.channel, keep_unity=False)

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model1[:,0], spectrum_model1[:,1], "o")
plt.plot(spectrum_target1[:,0], spectrum_target1[:,1], "o", markersize=3)
plt.legend(["_"])
plt.savefig("figures/" + "atypical_maps1.pdf")
plt.show()
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\3249944251.py:10: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_"])

# %% [markdown]
# ## Three Qubits

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model2[:,0], spectrum_model2[:,1], "o")
plt.plot(spectrum_target2[:,0], spectrum_target2[:,1], "o", markersize=3)
plt.savefig("figures/" + "atypical_maps2.pdf")
plt.show()
# Out:
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\tensorflow\python\framework\ops.py:307: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(self._numpy())
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model3[:,0], spectrum_model3[:,1], "o")
plt.plot(spectrum_target3[:,0], spectrum_target3[:,1], "o", markersize=3)
plt.savefig("figures/" + "atypical_maps3.pdf")
plt.show()
# Out:
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\tensorflow\python\framework\ops.py:307: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(self._numpy())
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model4[:,0], spectrum_model4[:,1], "o")
plt.plot(spectrum_target4[:,0], spectrum_target4[:,1], "o", markersize=3)
plt.savefig("figures/" + "atypical_maps4.pdf")
plt.show()
# Out:
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\tensorflow\python\framework\ops.py:307: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(self._numpy())
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
[[channel_target1, channel_target2, channel_target3, channel_target4],
 [model1, model2, model3, model4]]= loader("data/"+"atypical_maps_benchmark_3q.model")

spectrum_target1 = channel_spectrum(channel_target1, keep_unity=False)
spectrum_target2 = channel_spectrum(channel_target2, keep_unity=False)
spectrum_target3 = channel_spectrum(channel_target3, keep_unity=False)
spectrum_target4 = channel_spectrum(channel_target4, keep_unity=False)

spectrum_model1 = channel_spectrum(model1.channel, keep_unity=False)
spectrum_model2 = channel_spectrum(model2.channel, keep_unity=False)
spectrum_model3 = channel_spectrum(model3.channel, keep_unity=False)
spectrum_model4 = channel_spectrum(model4.channel, keep_unity=False)

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model1[:,0], spectrum_model1[:,1], "o")
plt.plot(spectrum_target1[:,0], spectrum_target1[:,1], "o", markersize=3)
plt.legend(["_"])
plt.savefig("figures/" + "atypical_maps1_3q.pdf")
plt.show()
# Out:
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\tensorflow\python\framework\ops.py:307: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(self._numpy())
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\3514919794.py:10: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_"])

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model2[:,0], spectrum_model2[:,1], "o")
plt.plot(spectrum_target2[:,0], spectrum_target2[:,1], "o", markersize=3)
plt.legend(["_"])
plt.savefig("figures/" + "atypical_maps2_3q.pdf")
plt.show()
# Out:
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\tensorflow\python\framework\ops.py:307: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(self._numpy())
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\1917982005.py:10: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_"])

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model3[:,0], spectrum_model3[:,1], "o")
plt.plot(spectrum_target3[:,0], spectrum_target3[:,1], "o", markersize=3)
plt.legend(["_"])
plt.savefig("figures/" + "atypical_maps3_3q.pdf")
plt.show()
# Out:
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\tensorflow\python\framework\ops.py:307: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(self._numpy())
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\3907321767.py:10: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_"])

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model4[:,0], spectrum_model4[:,1], "o")
plt.plot(spectrum_target4[:,0], spectrum_target4[:,1], "o", markersize=3)
plt.legend(["_"])
plt.savefig("figures/" + "atypical_maps4_3q.pdf")
plt.show()
# Out:
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\tensorflow\python\framework\ops.py:307: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(self._numpy())
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\244342551.py:10: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_"])

# %% [markdown]
# ## Sample and Noise Sensitivity

# %%
[[channel_target], [model_ns1, model_ns2, model_ns3]] = loader("data/" + "atypical_maps_robustness.model")

spectrum_target = channel_spectrum(channel_target)

spectrum_model1 = channel_spectrum(model_ns1.channel)
spectrum_model2 = channel_spectrum(model_ns2.channel)
spectrum_model3 = channel_spectrum(model_ns3.channel)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 [[channel_target], [model_ns1, model_ns2, model_ns3]] = loader("data/" + "atypical_maps_robustness.model")
#       3 spectrum_target = channel_spectrum(channel_target)
#       5 spectrum_model1 = channel_spectrum(model_ns1.channel)
#
# File c:\Users\krist\Documents\experimental-quantum-spectrum\analysis\atypical_quantum_maps\../../src_tf\utils.py:102, in loader(filename)
#     101 def loader(filename):
# --> 102     object = pickle.load(open(filename, "rb"))
#     104     return object
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/atypical_maps_robustness.model'

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_target[:,0], spectrum_target[:,1], "o")
plt.plot(spectrum_model1[:,0], spectrum_model1[:,1], "o")
#plt.plot(spectrum_model2[:,0], spectrum_model2[:,1], "o")
#plt.plot(spectrum_model3[:,0], spectrum_model3[:,1], "o")
plt.legend(["_","Ground Truth"], loc="lower left")
plt.show()
# Out:
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\tensorflow\python\framework\ops.py:307: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(self._numpy())
# c:\Users\krist\anaconda3\envs\env_phd\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\1373420408.py:12: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_","Ground Truth"], loc="lower left")

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_target[:,0], spectrum_target[:,1], "o")
plt.plot(spectrum_model1[:,0], spectrum_model1[:,1], "o")
plt.legend(["_","Ground Truth", "Shots=$10^2$, Samples=250"], loc="lower left")
plt.show()
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\3589216058.py:10: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_","Ground Truth", "Shots=$10^2$, Samples=250"], loc="lower left")

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_target[:,0], spectrum_target[:,1], "o")
#plt.plot(spectrum_model1[:,0], spectrum_model1[:,1], "o")
plt.plot(spectrum_model2[:,0], spectrum_model2[:,1], "ro")
#plt.plot(spectrum_model3[:,0], spectrum_model3[:,1], "o")
plt.legend(["_", "Ground Truth","Shots=$10^4$, Samples=1000"], loc="lower left")
plt.show()
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\2971609546.py:12: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_", "Ground Truth","Shots=$10^4$, Samples=1000"], loc="lower left")

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_target[:,0], spectrum_target[:,1], "o")
#plt.plot(spectrum_model1[:,0], spectrum_model1[:,1], "o")
#plt.plot(spectrum_model2[:,0], spectrum_model2[:,1], "o")
plt.plot(spectrum_model3[:,0], spectrum_model3[:,1], "go")
plt.legend(["_","Ground Truth", "Shots=$\infty$, #Samples=4000"], loc="lower left")
plt.show()
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_27948\1891841302.py:12: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(["_","Ground Truth", "Shots=$\infty$, #Samples=4000"], loc="lower left")
