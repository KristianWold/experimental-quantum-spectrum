# %% [markdown]
# # Clifford Circuit Spectrum

# %%
import sys
sys.path.insert(0, '../../src_tf/')

import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
import multiprocessing as mp
import random
import pickle

from qiskit.quantum_info import DensityMatrix, random_unitary
from qiskit.quantum_info import Operator
from scipy.linalg import sqrtm
from tqdm.notebook import tqdm
from math import ceil

from loss_functions import *
from optimization import *
from quantum_channel import *
from kraus_channels import *
from quantum_tools import *
from kraus_channels import *
from experimental import *
from spam import *
from scipy.stats import gaussian_kde
from quantum_circuits import *
from analysis import *
from utils import *

#np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(precision=4)

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
np.random.seed(43)
random.seed(43)
tf.random.set_seed(43)
n = 4
d = 2**n

model1 = fit_model(channel=KrausMap(d=d, 
                                    rank=64),
                  spam=SPAM(init = InitialState(d, c=0.9),
                            povm = CorruptionMatrix(d, c=0.9),
                            optimizer = tf.optimizers.Adam(learning_rate=0.01),
                            ),
                  loss_function = ProbabilityMSE(),
                  N_map=500,
                  N_spam=None,
                  num_iter_pretrain=0,
                  num_iter_map=4000,
                  num_iter_spam=4000,
                  filename="manila_4qubit_clifford0",
                 )

saver(model1, data_path("integrable_4qubit.model"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 7>()
#       4 n = 4
#       5 d = 2**n
# ----> 7 model1 = fit_model(channel=KrausMap(d=d,
#       8                                     rank=64),
#       9                   spam=SPAM(init = InitialState(d, c=0.9),
#      10                             povm = CorruptionMatrix(d, c=0.9),
#      11                             optimizer = tf.optimizers.Adam(learning_rate=0.01),
#      12                             ),
#      13                   loss_function = ProbabilityMSE(),
#      14                   N_map=500,
#      15                   N_spam=None,
#      16                   pretrain_iter_num = 0,
#      17                   num_iter_map=4000,
#      18                   num_iter_spam=4000,
#      19                   filename="manila_4qubit_clifford0",
#      20                  )
#      22 saver(model1, data_path("integrable_4qubit.model"))
#
# TypeError: fit_model() got an unexpected keyword argument 'pretrain_iter_num'

# %%
spectrum_model1 = channel_spectrum(model1.channel, use_coords=True)
spectrum_unitary1 = channel_spectrum(channel_target, use_coords=True)
spectrum_diluted1 = channel_spectrum(channel_diluted, use_coords=True)

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]

fig = plt.figure(figsize=(8,8), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum_model1[:,0], spectrum_model1[:,1], "bo")
plt.plot(spectrum_unitary1[:,0], spectrum_unitary1[:,1], "ro")
plt.plot(spectrum_diluted1[:,0], spectrum_diluted1[:,1], "go")

plt.legend(["Real Data", "Fitted Diluted Unitary", "Ideal Unitary"])

# %%
np.random.seed(43)
random.seed(43)
tf.random.set_seed(43)
n = 4
d = 2**n

model2 = fit_model(channel=KrausMap(d=d, 
                                    rank=64),
                  spam=SPAM(init = InitialState(d),
                            povm = CorruptionMatrix(d),
                            optimizer = tf.optimizers.Adam(learning_rate=0.01),
                            ),
                  loss_function = ProbabilityMSE(),
                  N_map=500,
                  N_spam=None,
                  num_iter_map=2000,
                  num_iter_spam=2000,
                  filename="manila_4qubit_nonintegrable0",
                 )

saver(model2, data_path("nonintegrable_4qubit.model"))
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
# 0.0008306639415087016
#   0%|          | 0/2000 [00:00<?, ?it/s]
