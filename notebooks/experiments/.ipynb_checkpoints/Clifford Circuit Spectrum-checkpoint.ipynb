# %% [markdown]
# # Clifford Circuit Spectrum

# %%
import sys
sys.path.insert(0, '../../src_tf/')

import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
import multiprocessing as mp
import random
import pickle

from qiskit.quantum_info import DensityMatrix, random_unitary, random_clifford
from qiskit.quantum_info import Operator
from scipy.linalg import sqrtm
from tqdm.notebook import tqdm
from math import ceil

from loss_functions import *
from optimization import *
from quantum_channel import *
from kraus_channels import *
from quantum_tools import *
from kraus_channels import *
from experimental import *
from spam import *
from scipy.stats import gaussian_kde
from quantum_circuits import *
from analysis import *
from utils import *

#np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(precision=4)

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
np.random.seed(43)
random.seed(43)
tf.random.set_seed(43)
n = 4
d = 2**n

model1 = fit_model(channel=KrausMap(d=d, 
                                    rank=64),
                  spam=SPAM(init = InitialState(d, c=0.9),
                            povm = CorruptionMatrix(d, c=0.9),
                            optimizer = tf.optimizers.Adam(learning_rate=0.01),
                            ),
                  loss_function = ProbabilityMSE(),
                  N_map=500,
                  N_spam=None,
                  num_iter_pretrain=0,
                  num_iter_map=4000,
                  num_iter_spam=4000,
                  filename="manila_4qubit_clifford0",
                 )

saver(model1, data_path("integrable_4qubit.model"))
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
# 0.0008424955595439244
#   0%|          | 0/4000 [00:00<?, ?it/s]

# %%
np.random.seed(43)
random.seed(43)
tf.random.set_seed(43)
n = 4
d = 2**n

model2 = fit_model(channel=KrausMap(d=d, 
                                    rank=64),
                  spam=SPAM(init = InitialState(d),
                            povm = CorruptionMatrix(d),
                            optimizer = tf.optimizers.Adam(learning_rate=0.01),
                            ),
                  loss_function = ProbabilityMSE(),
                  N_map=500,
                  N_spam=None,
                  num_iter_map=2000,
                  num_iter_spam=2000,
                  filename="manila_4qubit_nonintegrable0",
                 )

saver(model2, data_path("nonintegrable_4qubit.model"))
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]
# 0.0008306639415087016
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %% [markdown]
# ## Synthetic, Random Clifford

# %% [markdown]
# ### Three Qubits

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
rng = np.random.default_rng(42)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=2))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
rng = np.random.default_rng(42)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
rng = np.random.default_rng(42)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d**2))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(43)
random.seed(43)
tf.random.set_seed(43)
rng = np.random.default_rng(43)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=2))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(43)
random.seed(43)
tf.random.set_seed(43)
rng = np.random.default_rng(43)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(43)
random.seed(43)
tf.random.set_seed(43)
rng = np.random.default_rng(43)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d**2))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(44)
random.seed(44)
tf.random.set_seed(44)
rng = np.random.default_rng(44)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=2))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(44)
random.seed(44)
tf.random.set_seed(44)
rng = np.random.default_rng(44)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(44)
random.seed(44)
tf.random.set_seed(44)
rng = np.random.default_rng(44)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d**2))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %% [markdown]
# ## Four Qubits

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
rng = np.random.default_rng(42)

n = 4
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(43)
random.seed(43)
tf.random.set_seed(43)
rng = np.random.default_rng(43)

n = 4
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(44)
random.seed(44)
tf.random.set_seed(44)
rng = np.random.default_rng(44)

n = 4
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in range(5):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()

# %%
np.random.seed(44)
random.seed(44)
tf.random.set_seed(44)
rng = np.random.default_rng(44)

n = 5
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in tqdm(range(5)):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
rng = np.random.default_rng(42)

n = 5
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

for i in tqdm(range(5)):
    diluted_unitary = DilutedKrausMap(U=U, c=0.7, kraus_part = KrausMap(d, rank=d))
    spectrum = channel_spectrum(diluted_unitary)
    plt.plot(spectrum[:,0], spectrum[:,1], "o", markersize=3)

plt.show()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
rng = np.random.default_rng(42)

n = 3
d = 2**n

U = Operator(random_clifford(n, seed=rng)).data

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")


U1 = ChoiMapStatic(U, mode="unitary")
U2 = ChoiMapStatic(U@U, mode="unitary")
U3 = ChoiMapStatic(U@U@U, mode="unitary")
spectrum1 = channel_spectrum(U1)
spectrum2 = channel_spectrum(U2)
spectrum3 = channel_spectrum(U3)
plt.plot(spectrum1[:,0], spectrum1[:,1], "o", markersize=3)
plt.plot(spectrum2[:,0], spectrum2[:,1], "o", markersize=3)
plt.plot(spectrum3[:,0], spectrum3[:,1], "o", markersize=3)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 23>()
#      21 spectrum1 = channel_spectrum(U1)
#      22 spectrum2 = channel_spectrum(U2)
# ---> 23 spectrum3 = channel_spectrum(U3)
#      24 plt.plot(spectrum1[:,0], spectrum1[:,1], "o", markersize=3)
#      25 plt.plot(spectrum2[:,0], spectrum2[:,1], "o", markersize=3)
#
# NameError: name 'U3' is not defined
