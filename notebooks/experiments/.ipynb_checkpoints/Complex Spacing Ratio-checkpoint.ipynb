# %% [markdown]
# # Complex Spacing Ratio

# %%
import sys
sys.path.insert(0, '../../src_tf/')

import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
import multiprocessing as mp
import random
import pickle

from qiskit.quantum_info import DensityMatrix, random_unitary
from qiskit.quantum_info import Operator
from scipy.linalg import sqrtm
from tqdm.notebook import tqdm
from math import ceil

from loss_functions import *
from optimization import *
from quantum_channel import *
from kraus_channels import *
from quantum_tools import *
from experimental import *
from spam import *
from scipy.stats import gaussian_kde
from quantum_circuits import *
from analysis import *
from utils import *

#np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(precision=4)

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
def complex_spacing_ratio(spectrum):
    d = len(spectrum)
    spectrum = np.array(spectrum)[:,0]
    z_list = []
    for i in range(d):
        idx_NN = i
        dist_NN = float("inf")

        idx_NNN = i
        dist_NNN = float("inf")

        for j in range(d):
            if j != i:
                dist = np.abs(spectrum[i] - spectrum[j])
                if dist < dist_NN:
                    dist_NNN = dist_NN
                    idx_NNN = idx_NN

                    dist_NN = dist
                    idx_NN = j
                    
                if (dist > dist_NN) and (dist < dist_NNN):
                    dist_NNN = dist
                    idx_NNN = j

        z = (spectrum[idx_NN] -spectrum[i]) / (spectrum[idx_NNN] - spectrum[i])
        z_list.append(z)

    return np.array(z_list)


def generate_spam_benchmark(n=3, c1=1, c2=1):
    d = 2**n

    init_target = InitialState(d, c=c1)
    povm_target = POVM(d, c=c2)

    spam_target = SPAM(init = init_target,
                       povm = povm_target)
    
    return spam_target


def generate_spam_data(spam_target, N_spam=None, shots=1024):
    n = int(np.log2(spam_target.d))
    inputs_spam, _ = generate_pauliInput_circuits(n)
    N_spam = inputs_spam.shape[0]

    state = tf.repeat(spam_target.init.init[None,:,:], N_spam, axis=0)
    targets_spam = measurement(state, U_basis = inputs_spam, povm = spam_target.povm.povm)

    #add noise
    targets_spam = add_shot_noise(targets_spam, shots = shots)
    return inputs_spam, targets_spam


def generate_map_data(channel_target, spam_target, N_map=None, shots=1024):
    n = int(np.log2(channel_target.d))
    inputs_map, _ = generate_pauli_circuits(n = n, 
                                            circuit_target=None,  
                                            trace=False,
                                            N=N_map)
    U_prep, U_basis = inputs_map

    N_map = U_prep.shape[0]
    state = tf.repeat(tf.expand_dims(spam_target.init.init, axis=0), N_map, axis=0)
    state = apply_unitary(state, U_prep)
    state = channel_target.apply_channel(state)
    targets_map = measurement(state, U_basis, spam_target.povm.povm)
    
    #add noise
    targets_map = add_shot_noise(targets_map, shots = shots)

    return inputs_map, targets_map

# %%
n = 4
d = 2**n

np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

z_list1 = []

for i in tqdm(range(1)):
    U = circuit_to_matrix(integrable_circuit(n,n))
    channel_target = DilutedKrausMap(U=U, c=0.5, kraus_part=KrausMap(d,rank=8))
    spectrum = channel_spectrum(channel_target, use_coords=False, keep_real=False)
    z_list1.extend(complex_spacing_ratio(spectrum))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
plt.hist2d(np.real(z_list1), np.imag(z_list1), bins=20)
plt.show()

# %%
n = 4
d = 2**n

np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

z_list2 = []

for i in tqdm(range(1)):
    U = circuit_to_matrix(nonintegrable_circuit(n,n))
    channel_target = DilutedKrausMap(U=U, c=0.5, kraus_part=KrausMap(d,rank=8))
    spectrum = channel_spectrum(channel_target, use_coords=False, keep_real=False)
    z_list2.extend(complex_spacing_ratio(spectrum))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
plt.hist2d(np.real(z_list2), np.imag(z_list2), bins=20)
plt.show()

# %%
n = 4
d = 2**n

np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

channel_target1 = DilutedKrausMap(U=circuit_to_matrix(nonintegrable_circuit(n,n)), c=0.8, kraus_part=KrausMap(d,rank=2))
channel_target2 = DilutedKrausMap(U=circuit_to_matrix(integrable_circuit(n,n)), c=0.8, kraus_part=KrausMap(d,rank=2))

spectrum1 = channel_spectrum(channel_target1)
spectrum2 = channel_spectrum(channel_target2)

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(spectrum1[:,0], spectrum1[:,1], "o")
plt.plot(spectrum2[:,0], spectrum2[:,1], "o")

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

n = 3
d = 2**n

U = circuit_to_matrix(integrable_circuit(n,n))
channel_target1 = DilutedKrausMap(U=U, c=0.5, kraus_part=KrausMap(d,rank=2))

inputs_map, targets_map = generate_map_data(channel_target1, IdealSPAM(d), N_map= 2000-6**n, shots=1024)

model1 = ModelQuantumMap(channel = KrausMap(d = d, 
                                            rank = d**2,
                                            ),
                        loss_function = ProbabilityMSE(),
                        optimizer = tf.optimizers.Adam(learning_rate=0.01),
                        logger = Logger(loss_function = ProbabilityMSE(),
                                        loss_function_val = channel_fidelity_loss),
                       )

model1.train(inputs = inputs_map,
            targets = targets_map,
            inputs_val = None,
            targets_val = [channel_target1],
            num_iter = 2000,
            N = 500,
            )
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# 0.6096402564604915 -0.03695069105288077
# 0.19369082605669288 -0.2799214277485428
# 0.024214632776444204 -0.6604022214042341
# 0.011823187225058382 -0.7982988393449746
# 0.008602521662548702 -0.8659189022505966
# 0.007340847876906217 -0.9029315033258494
# 0.006786455468167234 -0.9247918652890321
# 0.006498089774370012 -0.9386350345792739
# 0.006355369655920665 -0.9478046158082926
# 0.006250687849203994 -0.9541561663873962
# 0.006197834651298591 -0.9587033995645434
# 0.006168290835765017 -0.96183593526303
# 0.0061323503656303445 -0.9641992517817308
# 0.006114105231056319 -0.9660211250163262
# 0.006106998289466987 -0.9673649703543402
# 0.006087629331585466 -0.9682403262517758
# 0.006078453992813957 -0.9693614862053777
# 0.006082404732553028 -0.9697024883209361
# 0.006074769239563426 -0.9703658615630264
# 0.006064078646825131 -0.9705991399427172
# tf.Tensor((0.006150373471762418+4.540091426898827e-20j), shape=(), dtype=complex128)
# 0.006069638517122008 -0.9709687789955096

# %%
spectrum_target1 = channel_spectrum(channel_target1, use_coords=False, keep_real=False)
spectrum_target2 = channel_spectrum(channel_target2, use_coords=False, keep_real=False)
spectrum_model1 = channel_spectrum(model1.channel, use_coords=False, keep_real=False)
spectrum_model2 = channel_spectrum(model2.channel, use_coords=False, keep_real=False)

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(np.real(spectrum_target1), np.imag(spectrum_target1), "o")
plt.plot(np.real(spectrum_model1), np.imag(spectrum_model1), "o")

# %%
z_target1 = complex_spacing_ratio(spectrum_target1)
z_target2 = complex_spacing_ratio(spectrum_target2)
z_model1 = complex_spacing_ratio(spectrum_model1)
z_model2 = complex_spacing_ratio(spectrum_model2)

# %%
fig = plt.figure(figsize=(4,3), dpi = 300, facecolor='w', edgecolor='k')

plt.plot(np.real(z_target1), np.imag(z_target1), 'bo', markersize=5)
plt.plot(np.real(z_model1), np.imag(z_model1), 'ro', markersize=4)
plt.show()

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

n = 3
d = 2**n

U = circuit_to_matrix(integrable_circuit(n,n))
channel_target1 = DilutedKrausMap(U=U, c=0.8, kraus_part=KrausMap(d,rank=2))

inputs_map, targets_map = generate_map_data(channel_target1, IdealSPAM(d), N_map= 2000-6**n, shots=1024)

model1 = ModelQuantumMap(channel = KrausMap(d = d, 
                                            rank = 3,
                                            ),
                        loss_function = ProbabilityMSE(),
                        optimizer = tf.optimizers.Adam(learning_rate=0.01),
                        logger = Logger(loss_function = ProbabilityMSE(),
                                        loss_function_val = channel_fidelity_loss),
                       )

model1.train(inputs = inputs_map,
            targets = targets_map,
            inputs_val = None,
            targets_val = [channel_target1],
            num_iter = 2000,
            N = 500,
            )
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# 0.8639385228850553 -0.03754810824239284
# 0.28455512260537064 -0.36126949676516174
# 0.042800660351794084 -0.7124914325981235
# 0.024072846089915112 -0.8191841836396507
# 0.018225970306881268 -0.8835982199041937
# 0.013992693560454222 -0.930549723201615
# 0.010745007811745423 -0.9614232358947029
# 0.008633541722628544 -0.9794971961488
# 0.00741049391900824 -0.989712678802521
# 0.006765536370023693 -0.9950066548142349
# 0.0064961713700512165 -0.9973323312219153
# 0.0063628690461001655 -0.9983443794903898
# 0.006283550505637816 -0.9988957658522616
# 0.006331716917964902 -0.9988437405313326
# 0.006320950671825566 -0.9990555733953032
# 0.00628150421966536 -0.9990681413586336
# 0.006289646653913779 -0.9990830886038659
# 0.006357810143703175 -0.9988384805434187
# 0.006289818553173321 -0.9990275407364732
# 0.006278093216814009 -0.9990674107363987
# tf.Tensor((0.006292068699587986+2.1464414210600733e-19j), shape=(), dtype=complex128)
# 0.006280795262922797 -0.9990316070373761

# %%
spectrum_target1 = channel_spectrum(channel_target1, use_coords=False, keep_real=False)
spectrum_target2 = channel_spectrum(channel_target2, use_coords=False, keep_real=False)
spectrum_model1 = channel_spectrum(model1.channel, use_coords=False, keep_real=False)
spectrum_model2 = channel_spectrum(model2.channel, use_coords=False, keep_real=False)

z_target1 = complex_spacing_ratio(spectrum_target1)
z_target2 = complex_spacing_ratio(spectrum_target2)
z_model1 = complex_spacing_ratio(spectrum_model1)
z_model2 = complex_spacing_ratio(spectrum_model2)

# %%
t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]
fig = plt.figure(figsize=(6,6), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)
plt.plot(*circle, "k")

plt.plot(np.real(spectrum_target1), np.imag(spectrum_target1), "o")
plt.plot(np.real(spectrum_model1), np.imag(spectrum_model1), "o")

# %%
fig = plt.figure(figsize=(4,3), dpi = 300, facecolor='w', edgecolor='k')

plt.plot(np.real(z_target1), np.imag(z_target1), 'bo', markersize=5)
plt.plot(np.real(z_model1), np.imag(z_model1), 'ro', markersize=4)
plt.show()
