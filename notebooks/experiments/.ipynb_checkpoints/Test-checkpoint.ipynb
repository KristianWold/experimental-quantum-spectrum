# %% [markdown]
# # Spectral Construction

# %%
import sys
sys.path.insert(0, '../../src_tf/')

import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
import multiprocessing as mp
import random
import pickle

from qiskit.quantum_info import DensityMatrix
from qiskit.quantum_info import Operator
from scipy.linalg import sqrtm
from tqdm.notebook import tqdm

from loss_functions import *
from optimization import *
from quantum_maps import *
from quantum_tools import *
from experiments import *

#np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(precision=4)

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %% [markdown]
# ##

# %%
n = 3
d = 2**n

np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

kraus_target = KrausMap(d = d, 
                        rank = 4,
                        )

kraus_model = KrausMap(d = d, 
                       rank = d**2,
                      )

choi_target = maps_to_choi([kraus_target])
choi_model = maps_to_choi([kraus_model])

spectrum_target = choi_spectrum(choi_target, real=True)
spectrum_model = choi_spectrum(choi_model, real=True)

# %%
print(spectrum_target.shape)
# Out:
# (64, 2)

# %%
model = ModelQuantumMap(
                        q_map = kraus_model,
                        loss = SpectrumDistance(sigma=0.1),
                        optimizer = tf.optimizers.Adam(learning_rate=0.01),
                        )

# %%
model.train(inputs = [spectrum_target],
            targets = [],
            num_iter = 89,
            N = 1,
            use_batch = False,
            )
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Step:0, train: 1040.07409, val: 0.00000
# Step:1, train: 988.22638, val: 0.00000
# Step:2, train: 942.45984, val: 0.00000
# Step:3, train: 901.03190, val: 0.00000
# Step:4, train: 863.00875, val: 0.00000
# Step:5, train: 827.84512, val: 0.00000
# Step:6, train: 795.13836, val: 0.00000
# Step:7, train: 764.57200, val: 0.00000
# Step:8, train: 735.89907, val: 0.00000
# Step:9, train: 708.93032, val: 0.00000
# Step:10, train: 683.46535, val: 0.00000
# Step:11, train: 659.35742, val: 0.00000
# Step:12, train: 636.48494, val: 0.00000
# Step:13, train: 614.73329, val: 0.00000
# Step:14, train: 594.00900, val: 0.00000
# Step:15, train: 574.21076, val: 0.00000
# Step:16, train: 555.26081, val: 0.00000
# Step:17, train: 537.09411, val: 0.00000
# Step:18, train: 519.65507, val: 0.00000
# Step:19, train: 502.89997, val: 0.00000
# Step:20, train: 486.79697, val: 0.00000
# Step:21, train: 471.28823, val: 0.00000
# Step:22, train: 456.34106, val: 0.00000
# Step:23, train: 441.90287, val: 0.00000
# Step:24, train: 427.95980, val: 0.00000
# Step:25, train: 414.46642, val: 0.00000
# Step:26, train: 401.42815, val: 0.00000
# Step:27, train: 388.81500, val: 0.00000
# Step:28, train: 376.59433, val: 0.00000
# Step:29, train: 364.74829, val: 0.00000
# Step:30, train: 353.27014, val: 0.00000
# Step:31, train: 342.14273, val: 0.00000
# Step:32, train: 331.33882, val: 0.00000
# Step:33, train: 320.84054, val: 0.00000
# Step:34, train: 310.63629, val: 0.00000
# Step:35, train: 300.71402, val: 0.00000
# Step:36, train: 291.05607, val: 0.00000
# Step:37, train: 281.66243, val: 0.00000
# Step:38, train: 272.51714, val: 0.00000
# Step:39, train: 263.60828, val: 0.00000
# Step:40, train: 254.92585, val: 0.00000
# Step:41, train: 246.45888, val: 0.00000
# Step:42, train: 238.19779, val: 0.00000
# Step:43, train: 230.13806, val: 0.00000
# Step:44, train: 222.26721, val: 0.00000
# Step:45, train: 214.56256, val: 0.00000
# Step:46, train: 207.04865, val: 0.00000
# Step:47, train: 199.71064, val: 0.00000
# Step:48, train: 192.54589, val: 0.00000
# Step:49, train: 185.55116, val: 0.00000
# Step:50, train: 178.71996, val: 0.00000
# Step:51, train: 172.04797, val: 0.00000
# Step:52, train: 165.53077, val: 0.00000
# Step:53, train: 159.16343, val: 0.00000
# Step:54, train: 152.93641, val: 0.00000
# Step:55, train: 146.84553, val: 0.00000
# Step:56, train: 140.89250, val: 0.00000
# Step:57, train: 135.07305, val: 0.00000
# Step:58, train: 129.38450, val: 0.00000
# Step:59, train: 123.81806, val: 0.00000
# Step:60, train: 118.37476, val: 0.00000
# Step:61, train: 113.05124, val: 0.00000
# Step:62, train: 107.83941, val: 0.00000
# Step:63, train: 102.73879, val: 0.00000
# Step:64, train: 97.74554, val: 0.00000
# Step:65, train: 92.85485, val: 0.00000
# Step:66, train: 88.06605, val: 0.00000
# Step:67, train: 83.37528, val: 0.00000
# Step:68, train: 78.77450, val: 0.00000
# Step:69, train: 74.26556, val: 0.00000
# Step:70, train: 69.84898, val: 0.00000
# Step:71, train: 65.52236, val: 0.00000
# Step:72, train: 61.28300, val: 0.00000
# Step:73, train: 57.12932, val: 0.00000
# Step:74, train: 53.05902, val: 0.00000
# Step:75, train: 49.06906, val: 0.00000
# Step:76, train: 45.15518, val: 0.00000
# Step:77, train: 41.31772, val: 0.00000
# Step:78, train: 37.55382, val: 0.00000
# Step:79, train: 33.85790, val: 0.00000
# Step:80, train: 30.22983, val: 0.00000
# Step:81, train: 26.66625, val: 0.00000
# Step:82, train: 23.16739, val: 0.00000
# Step:83, train: 19.73253, val: 0.00000
# Step:84, train: 16.35961, val: 0.00000
# Step:85, train: 13.04733, val: 0.00000
# Step:86, train: 9.79471, val: 0.00000
# Step:87, train: 6.59955, val: 0.00000
# Step:88, train: 3.46077, val: 0.00000
# Step:89, train: 0.37744, val: 0.00000
# Step:90, train: 2.65291, val: 0.00000
# Step:91, train: 5.63064, val: 0.00000
# Step:92, train: 8.55687, val: 0.00000
# Step:93, train: 11.43410, val: 0.00000
# Step:94, train: 14.26242, val: 0.00000
# Step:95, train: 17.04388, val: 0.00000
# Step:96, train: 19.77909, val: 0.00000
# Step:97, train: 22.46892, val: 0.00000
# Step:98, train: 25.11526, val: 0.00000
# Step:99, train: 27.71897, val: 0.00000
# 27.71896568169643 0

# %%
choi_model = maps_to_choi([kraus_model])
spectrum_model = choi_spectrum(choi_model, real=True)

t = np.linspace(0, 2*np.pi, 1000)
circle = [np.sin(t), np.cos(t)]

fig=plt.figure(figsize=(8,8), dpi = 300, facecolor='w', edgecolor='k')
plt.plot(spectrum_target[:,0], spectrum_target[:,1], "o")
plt.plot(spectrum_model[:,0], spectrum_model[:,1], "o")
plt.plot(*circle)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.show()

# %%
steady = choi_steady_state(choi_model1)
steady = steady/tf.linalg.trace(steady)

print(tf.linalg.trace(steady))
print(tf.linalg.trace(steady@steady))

# %%
model.zero_optimizer()
model.loss.sigma=0.025

# %%
model.train(inputs = [spectrum_target],
            targets = [],
            num_iter = 500,
            N = 1,
            use_batch = False,
            )
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Step:0, train: 2743.11993, val: 0.00000
# Step:1, train: 2722.62564, val: 0.00000
# Step:2, train: 2703.55931, val: 0.00000
# Step:3, train: 2686.12525, val: 0.00000
# Step:4, train: 2670.54702, val: 0.00000
# Step:5, train: 2656.96430, val: 0.00000
# Step:6, train: 2645.31603, val: 0.00000
# Step:7, train: 2635.21313, val: 0.00000
# Step:8, train: 2626.17026, val: 0.00000
# Step:9, train: 2617.60660, val: 0.00000
# Step:10, train: 2609.21539, val: 0.00000
# Step:11, train: 2600.89763, val: 0.00000
# Step:12, train: 2592.81071, val: 0.00000
# Step:13, train: 2585.25375, val: 0.00000
# Step:14, train: 2578.62666, val: 0.00000
# Step:15, train: 2573.40206, val: 0.00000
# Step:16, train: 2569.89965, val: 0.00000
# Step:17, train: 2568.00323, val: 0.00000
# Step:18, train: 2567.05407, val: 0.00000
# Step:19, train: 2566.18374, val: 0.00000
# Step:20, train: 2565.16099, val: 0.00000
# Step:21, train: 2564.20934, val: 0.00000
# Step:22, train: 2563.53523, val: 0.00000
# Step:23, train: 2563.12560, val: 0.00000
# Step:24, train: 2562.84747, val: 0.00000
# Step:25, train: 2562.54784, val: 0.00000
# Step:26, train: 2562.14554, val: 0.00000
# Step:27, train: 2561.62347, val: 0.00000
# Step:28, train: 2561.04547, val: 0.00000
# Step:29, train: 2560.49833, val: 0.00000
# Step:30, train: 2560.04817, val: 0.00000
# Step:31, train: 2559.71269, val: 0.00000
# Step:32, train: 2559.46848, val: 0.00000
# Step:33, train: 2559.28440, val: 0.00000
# Step:34, train: 2559.14524, val: 0.00000
# Step:35, train: 2559.04264, val: 0.00000
# Step:36, train: 2558.96032, val: 0.00000
# Step:37, train: 2558.88180, val: 0.00000
# Step:38, train: 2558.80474, val: 0.00000
# Step:39, train: 2558.73747, val: 0.00000
# Step:40, train: 2558.68183, val: 0.00000
# Step:41, train: 2558.62943, val: 0.00000
# Step:42, train: 2558.57989, val: 0.00000
# Step:43, train: 2558.54176, val: 0.00000
# Step:44, train: 2558.51351, val: 0.00000
# Step:45, train: 2558.48709, val: 0.00000
# Step:46, train: 2558.46371, val: 0.00000
# Step:47, train: 2558.44869, val: 0.00000
# Step:48, train: 2558.43721, val: 0.00000
# Step:49, train: 2558.42443, val: 0.00000
# Step:50, train: 2558.41567, val: 0.00000
# Step:51, train: 2558.41067, val: 0.00000
# Step:52, train: 2558.40400, val: 0.00000
# Step:53, train: 2558.39812, val: 0.00000
# Step:54, train: 2558.39557, val: 0.00000
# Step:55, train: 2558.39174, val: 0.00000
# Step:56, train: 2558.38748, val: 0.00000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 model.train(inputs = [spectrum_target],
#       2             targets = [],
#       3             num_iter = 500,
#       4             N = 1,
#       5             use_batch = False,
#       6             )
#
# File ~\Documents\ModelNISQ\notebooks\experiments\../../src_tf\optimization.py:68, in ModelQuantumMap.train(self, inputs, targets, inputs_val, targets_val, num_iter, N, verbose, use_batch)
#      65     self.q_map.generate_map()
#      66     loss = self.loss(self.q_map, inputs_batch, targets_batch)
# ---> 68 grads = tape.gradient(loss, self.q_map.parameter_list)
#      69 self.optimizer.apply_gradients(zip(grads, self.q_map.parameter_list))
#      71 if targets_val is None:
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\eager\backprop.py:1113, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1107   output_gradients = (
#    1108       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1109           output_gradients))
#    1110   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1111                       for x in output_gradients]
# -> 1113 flat_grad = imperative_grad.imperative_grad(
#    1114     self._tape,
#    1115     flat_targets,
#    1116     flat_sources,
#    1117     output_gradients=output_gradients,
#    1118     sources_raw=flat_sources_raw,
#    1119     unconnected_gradients=unconnected_gradients)
#    1121 if not self._persistent:
#    1122   # Keep track of watched variables before setting tape to None
#    1123   self._watched_variables = self._tape.watched_variables()
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\eager\backprop.py:160, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     158     gradient_name_scope += forward_pass_name_scope + "/"
#     159   with ops.name_scope(gradient_name_scope):
# --> 160     return grad_fn(mock_op, *out_grads)
#     161 else:
#     162   return grad_fn(mock_op, *out_grads)
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\ops\math_grad.py:586, in _NegGrad(_, grad)
#     583 @ops.RegisterGradient("Neg")
#     584 def _NegGrad(_, grad):
#     585   """Returns -grad."""
# --> 586   return -grad
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6748, in neg(x, name)
#    6746 if tld.is_eager:
#    6747   try:
# -> 6748     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6749       _ctx, "Neg", name, x)
#    6750     return _result
#    6751   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
choi_model1 = maps_to_choi([kraus_model])
spectrum_model = choi_spectrum(choi_model1)

t = np.linspace(0, 2*np.pi, 1000)
circle = [np.sin(t), np.cos(t)]

fig=plt.figure(figsize=(8,8), dpi = 300, facecolor='w', edgecolor='k')
plt.plot(*spectrum_target, "o")
plt.plot(*spectrum_model, "o")
plt.plot(*circle)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.show()
