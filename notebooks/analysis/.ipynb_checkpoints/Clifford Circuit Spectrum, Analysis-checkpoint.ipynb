# %% [markdown]
# # Clifford Circuit Spectrum

# %%
import sys
sys.path.insert(0, '../../src_tf/')

import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
import multiprocessing as mp
import random
import pickle

from qiskit.quantum_info import DensityMatrix, random_unitary
from qiskit.quantum_info import Operator
from scipy.linalg import sqrtm
from tqdm.notebook import tqdm
from math import ceil

from loss_functions import *
from optimization import *
from quantum_channel import *
from kraus_channels import *
from quantum_tools import *
from kraus_channels import *
from experimental import *
from spam import *
from scipy.stats import gaussian_kde
from quantum_circuits import *
from analysis import *
from utils import *

#np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(precision=4)

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
def resample_diluted(diluted_channel, num_samples, integrable=True):
    d = diluted_channel.d
    c = diluted_channel.c
    rank = diluted_channel.rank
    
    n = int(np.log2(d))
    spectrum_resample_list = []
    for i in tqdm(range(num_samples)):
        if integrable:
            U = circuit_to_matrix(integrabel_circuit(n,n))
        else:
            U = circuit_to_matrix(non_integrabel(n,n))
            
        diluted_resample = DilutedKrausMap(U=U, c=c, kraus_part=KrausMap(d, rank = rank))
        spectrum_resample = channel_spectrum(diluted_resample, use_coords=True, keep_real=False)
        spectrum_resample_list.append(spectrum_resample)
    
    spectrum_resample = np.real(np.concatenate(spectrum_resample_list))
    
    return spectrum_resample

# %%
def resample_diluted(diluted_channel, U = None, num_samples = None):
    d = diluted_channel.d
    c = diluted_channel.c
    rank = diluted_channel.rank
    
    n = int(np.log2(d))
    spectrum_resample_list = []
    for i in tqdm(range(num_samples)):
            
        diluted_resample = DilutedKrausMap(U=U, c=c, kraus_part=KrausMap(d, rank = rank))
        spectrum_resample = channel_spectrum(diluted_resample, use_coords=True, keep_real=False)
        spectrum_resample_list.append(spectrum_resample)
    
    spectrum_resample = np.real(np.concatenate(spectrum_resample_list))
    
    return spectrum_resample

# %%
model1 = loader(data_path("integrable_4qubit.model"))
d = model1.channel.d

np.random.seed(42)
random.seed(42)

circuit = integrabel_circuit(4, 4)
U = circuit_to_matrix(circuit)

channel_unitary = ChoiMapStatic(U, mode="unitary")
channel_diluted = DilutedKrausMap(U=U, c=0.49, kraus_part=KrausMap(d, rank=7))

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
rng = np.random.default_rng(seed=42)

spectrum_resample = resample_diluted(channel_diluted, U=U, num_samples = 1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
spectrum_model1 = channel_spectrum(model1.channel, use_coords=True)
spectrum_unitary1 = channel_spectrum(channel_unitary, use_coords=True)

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]

fig = plt.figure(figsize=(8,8), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)


plt.hist2d(spectrum_resample[:,0], spectrum_resample[:,1], bins = np.linspace(-1, 1, 100))
plt.plot(*circle, "w")
plt.plot(spectrum_model1[:,0], spectrum_model1[:,1], "ro", markersize=3)
plt.plot(spectrum_unitary1[:,0], spectrum_unitary1[:,1], "bo", markersize=3)

plt.legend(["_", "Real Data", "Ideal Unitary"], loc="lower right")
plt.savefig(image_path("integrateble_circuit.pdf"), bbox_inches='tight')
plt.show()
# Out:
# C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\matplotlib\cbook\__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\krisw\AppData\Local\Temp\ipykernel_14676\3163694104.py:17: UserWarning: The label '_' of <matplotlib.lines.Line2D object at 0x0000026739FBD420> starts with '_'. It is thus excluded from the legend.
#   plt.legend(["_", "Real Data", "Ideal Unitary"], loc="lower right")

# %%
model2 = loader(data_path("nonintegrable_4qubit.model"))
d = model2.channel.d

np.random.seed(42)
random.seed(42)

circuit = nonintegrabel_circuit(4, 4)
U = circuit_to_matrix(circuit)

channel_unitary = ChoiMapStatic(U, mode="unitary")
channel_diluted = DilutedKrausMap(U=U, c=0.4, kraus_part=KrausMap(d, rank=12))

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
rng = np.random.default_rng(seed=42)

spectrum_resample = resample_diluted(channel_diluted, U=U, num_samples = 1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [68], in <cell line: 6>()
#       3 tf.random.set_seed(42)
#       4 rng = np.random.default_rng(seed=42)
# ----> 6 spectrum_resample = resample_diluted(channel_diluted, U=U, num_samples = 1000)
#
# Input In [63], in resample_diluted(diluted_channel, U, num_samples)
#       8 for i in tqdm(range(num_samples)):
#      10     diluted_resample = DilutedKrausMap(U=U, c=c, kraus_part=KrausMap(d, rank = rank))
# ---> 11     spectrum_resample = channel_spectrum(diluted_resample, use_coords=True, keep_real=False)
#      12     spectrum_resample_list.append(spectrum_resample)
#      14 spectrum_resample = np.real(np.concatenate(spectrum_resample_list))
#
# File ~\Documents\ModelNISQ\notebooks\analysis\../../src_tf\spectrum.py:20, in channel_spectrum(input, use_coords, keep_real, keep_unity, tol)
#      18 def channel_spectrum(input, use_coords=True, keep_real=True, keep_unity=True, tol=1e-4):
#      19     if isinstance(input, Channel):
# ---> 20         eig, _ = tf.linalg.eig(reshuffle(input.choi))
#      21         eig = tf.expand_dims(eig, axis=1)
#      22     else:
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\ops\linalg_ops.py:406, in eig(tensor, name)
#     404 elif tensor.dtype == dtypes.float64 or tensor.dtype == dtypes.complex128:
#     405   out_dtype = dtypes.complex128
# --> 406 e, v = gen_linalg_ops.eig(tensor, Tout=out_dtype, compute_v=True, name=name)
#     407 return e, v
#
# File C:\Program Files\Anaconda3\envs\env_qiskit\lib\site-packages\tensorflow\python\ops\gen_linalg_ops.py:939, in eig(input, Tout, compute_v, name)
#     937 if tld.is_eager:
#     938   try:
# --> 939     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     940       _ctx, "Eig", name, input, "compute_v", compute_v, "Tout", Tout)
#     941     _result = _EigOutput._make(_result)
#     942     return _result
#
# KeyboardInterrupt:

# %%
spectrum_model2 = channel_spectrum(model2.channel, use_coords=True)
spectrum_unitary2 = channel_spectrum(channel_unitary, use_coords=True)

t = np.linspace(0, 2*np.pi, 100)
circle = [np.sin(t), np.cos(t)]

fig = plt.figure(figsize=(8,8), dpi = 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_aspect(1)


plt.hist2d(spectrum_resample[:,0], spectrum_resample[:,1], bins = np.linspace(-1, 1, 100))
plt.plot(*circle, "k")
plt.plot(spectrum_model2[:,0], spectrum_model2[:,1], "ro", markersize=3)
plt.plot(spectrum_unitary2[:,0], spectrum_unitary2[:,1], "go")

plt.legend(["_", "Real Data", "Fitted Diluted Unitary", "Ideal Unitary"], loc="lower right")
plt.savefig(image_path("nonintegrateble_circuit.pdf"), bbox_inches='tight')
plt.show()
